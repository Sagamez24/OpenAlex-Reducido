# %%
import json
import pandas as pd
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('/content/drive/MyDrive/json/openalexco.json','r') as miarchivo:
    objeto=miarchivo.read()
objeto=json.loads(objeto)

# %%
# https://ror.org/03bp5hc83 ror de la udea

# %%
objeto=[ c for c in objeto if any(
    [ any([i.get('ror')=="https://ror.org/03bp5hc83" for i in a.get('institutions')]) 
    for a in c.get('authorships')])
]

# %%
[ [ [i.get('ror')=="https://ror.org/03bp5hc83" for i in a.get('institutions')] for a in c.get('authorships')] for c in objeto][0]
# Out:
# [[True], [], [], []]

# %%
def filter_concept(concepts,concept='Physics'):
    return any([True for c in concepts if c.get('display_name')==concept])

# %%
def filter_ror(authorships,ror="https://ror.org/03bp5hc83"):
  return any([any([i.get('ror')=="https://ror.org/03bp5hc83" for i in a.get('institutions')])  for a in authorships])

# %%
ph=[d for d in objeto if filter_concept(d.get('concepts'),concept='Physics') ] #Aqui ya se filtro los conceptos de Física
del(objeto)

# %%
len(ph)
# Out:
# 1886

# %%
pp    = [d for d in ph if (filter_concept(d.get('concepts'),concept='Condensed matter physics') or
                           filter_concept(d.get('concepts'),concept='Nanotechnology')
                           ) ]
len(pp)
# Out:
# 260

# %%
pp_level2=[d for d in ph if (filter_concept(d.get('concepts'),concept='Thin film') or
                             filter_concept(d.get('concepts'),concept='Ferromagnetism')
                             ) ]
len(pp_level2)
# Out:
# 12

# %%
import pandas as pd

# %%
df=pd.DataFrame(pp_level2)
df
# Out:
#                                   id  \
# 0   https://openalex.org/W2940095680
# 1   https://openalex.org/W3098333922
# 2   https://openalex.org/W2592609880
# 3   https://openalex.org/W1851763813
# 4   https://openalex.org/W1964737175
# 5   https://openalex.org/W1964672547
# 6   https://openalex.org/W2038510174
# 7   https://openalex.org/W1969751937
# 8   https://openalex.org/W2059352955
# 9   https://openalex.org/W2107636469
# 10  https://openalex.org/W2061958142
# 11  https://openalex.org/W2052868994
#
#                                                   doi  \
# 0         https://doi.org/10.1103/physrevb.101.054419
# 1          https://doi.org/10.1038/s41598-018-28598-1
# 2          https://doi.org/10.1103/physrevb.95.104407
# 3                                                None
# 4          https://doi.org/10.1140/epjb/e2014-40712-6
# 5          https://doi.org/10.1016/j.jmmm.2013.05.003
# 6           https://doi.org/10.1007/s10948-012-1651-9
# 7          https://doi.org/10.1103/physrevb.83.184432
# 8          https://doi.org/10.1103/physrevb.80.052403
# 9      https://doi.org/10.1016/j.physleta.2006.06.036
# 10        https://doi.org/10.1016/j.physb.2006.05.269
# 11  https://doi.org/10.1002/1521-3951(200007)220:1...
#
#                                                 title  \
# 0   Tailoring dual reversal modes by helicity cont...
# 1   Change in the magnetic configurations of tubul...
# 2   Conduction electrons mediating the evolution f...
# 3   INFLUÊNCIA DE PROCESSO DE MOAGEM DE BOLAS SOBR...
# 4   Ornstein-Zernike correlations and magnetic ord...
# 5   Interface exchange parameters in La2/3Ca1/3Mn3...
# 6   Influence of the Competition Between Dipolar a...
# 7   Pseudocritical behavior of ferromagnetic pure ...
# 8   Magnetic depth profile of a modulation-doped L...
# 9   Monte Carlo study of the change of critical te...
# 10  Critical behavior of ferromagnetic Ising thin ...
# 11  Hyperfine Magnetic Field Distributions of Fe0....
#
#                                          display_name  publication_year  \
# 0   Tailoring dual reversal modes by helicity cont...              2020
# 1   Change in the magnetic configurations of tubul...              2018
# 2   Conduction electrons mediating the evolution f...              2017
# 3   INFLUÊNCIA DE PROCESSO DE MOAGEM DE BOLAS SOBR...              2014
# 4   Ornstein-Zernike correlations and magnetic ord...              2014
# 5   Interface exchange parameters in La2/3Ca1/3Mn3...              2013
# 6   Influence of the Competition Between Dipolar a...              2012
# 7   Pseudocritical behavior of ferromagnetic pure ...              2011
# 8   Magnetic depth profile of a modulation-doped L...              2009
# 9   Monte Carlo study of the change of critical te...              2007
# 10  Critical behavior of ferromagnetic Ising thin ...              2006
# 11  Hyperfine Magnetic Field Distributions of Fe0....              2000
#
#    publication_date                                                ids  \
# 0        2020-02-13  {'openalex': 'https://openalex.org/W2940095680...
# 1        2018-06-04  {'openalex': 'https://openalex.org/W3098333922...
# 2        2017-03-08  {'openalex': 'https://openalex.org/W2592609880...
# 3        2014-05-01  {'openalex': 'https://openalex.org/W1851763813...
# 4        2014-03-10  {'openalex': 'https://openalex.org/W1964737175...
# 5        2013-10-01  {'openalex': 'https://openalex.org/W1964672547...
# 6        2012-05-31  {'openalex': 'https://openalex.org/W2038510174...
# 7        2011-05-27  {'openalex': 'https://openalex.org/W1969751937...
# 8        2009-08-17  {'openalex': 'https://openalex.org/W2059352955...
# 9        2007-01-01  {'openalex': 'https://openalex.org/W2107636469...
# 10       2006-10-01  {'openalex': 'https://openalex.org/W2061958142...
# 11       2000-07-01  {'openalex': 'https://openalex.org/W2052868994...
#
#                                            host_venue             type  \
# 0   {'id': 'https://openalex.org/V4210237713', 'is...  journal-article
# 1   {'id': 'https://openalex.org/V196734849', 'iss...  journal-article
# 2   {'id': 'https://openalex.org/V6791298', 'issn_...  journal-article
# 3   {'id': None, 'issn_l': None, 'issn': None, 'di...             None
# 4   {'id': 'https://openalex.org/V9051360', 'issn_...  journal-article
# 5   {'id': 'https://openalex.org/V3649266', 'issn_...  journal-article
# 6   {'id': 'https://openalex.org/V89963981', 'issn...  journal-article
# 7   {'id': 'https://openalex.org/V6791298', 'issn_...  journal-article
# 8   {'id': 'https://openalex.org/V6791298', 'issn_...  journal-article
# 9   {'id': 'https://openalex.org/V104875562', 'iss...  journal-article
# 10  {'id': 'https://openalex.org/V34296711', 'issn...  journal-article
# 11  {'id': 'https://openalex.org/V71689831', 'issn...  journal-article
#
#                                           open_access  ...  \
# 0   {'is_oa': True, 'oa_status': 'green', 'oa_url'...  ...
# 1   {'is_oa': True, 'oa_status': 'gold', 'oa_url':...  ...
# 2   {'is_oa': True, 'oa_status': 'green', 'oa_url'...  ...
# 3   {'is_oa': True, 'oa_status': None, 'oa_url': N...  ...
# 4   {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 5   {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 6   {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 7   {'is_oa': True, 'oa_status': 'green', 'oa_url'...  ...
# 8   {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 9   {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 10  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 11  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
#
#                                              concepts  mesh  \
# 0   [{'id': 'https://openalex.org/C2775859700', 'w...    []
# 1   [{'id': 'https://openalex.org/C26873012', 'wik...    []
# 2   [{'id': 'https://openalex.org/C155355069', 'wi...    []
# 3   [{'id': 'https://openalex.org/C192562407', 'wi...    []
# 4   [{'id': 'https://openalex.org/C26873012', 'wik...    []
# 5   [{'id': 'https://openalex.org/C95914496', 'wik...    []
# 6   [{'id': 'https://openalex.org/C26873012', 'wik...    []
# 7   [{'id': 'https://openalex.org/C26873012', 'wik...    []
# 8   [{'id': 'https://openalex.org/C26873012', 'wik...    []
# 9   [{'id': 'https://openalex.org/C121332964', 'wi...    []
# 10  [{'id': 'https://openalex.org/C26873012', 'wik...    []
# 11  [{'id': 'https://openalex.org/C26873012', 'wik...    []
#
#                                 alternate_host_venues  \
# 0   [{'id': None, 'display_name': 'Universitat de ...
# 1   [{'id': 'https://openalex.org/V196734849', 'di...
# 2   [{'id': None, 'display_name': 'Red Federada de...
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7   [{'id': None, 'display_name': 'arXiv', 'type':...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
#
#                                      referenced_works  \
# 0   [https://openalex.org/W1837059249, https://ope...
# 1   [https://openalex.org/W1607710824, https://ope...
# 2                                                  []
# 3                                                  []
# 4   [https://openalex.org/W2314330190, https://ope...
# 5   [https://openalex.org/W264627396, https://open...
# 6   [https://openalex.org/W1979565605, https://ope...
# 7   [https://openalex.org/W1599991186, https://ope...
# 8   [https://openalex.org/W2052499507, https://ope...
# 9   [https://openalex.org/W592496656, https://open...
# 10  [https://openalex.org/W2031794121, https://ope...
# 11  [https://openalex.org/W1987528470, https://ope...
#
#                                         related_works  \
# 0   [https://openalex.org/W26422503, https://opena...
# 1   [https://openalex.org/W122106518, https://open...
# 2   [https://openalex.org/W16275567, https://opena...
# 3                                                  []
# 4   [https://openalex.org/W1993576526, https://ope...
# 5   [https://openalex.org/W1611680015, https://ope...
# 6   [https://openalex.org/W1487676161, https://ope...
# 7   [https://openalex.org/W2057520797, https://ope...
# 8   [https://openalex.org/W2041154130, https://ope...
# 9   [https://openalex.org/W821942989, https://open...
# 10  [https://openalex.org/W1969494574, https://ope...
# 11  [https://openalex.org/W2010079024, https://ope...
#
#                                      cited_by_api_url  \
# 0   https://api.openalex.org/works?filter=cites:W2...
# 1   https://api.openalex.org/works?filter=cites:W3...
# 2   https://api.openalex.org/works?filter=cites:W2...
# 3   https://api.openalex.org/works?filter=cites:W1...
# 4   https://api.openalex.org/works?filter=cites:W1...
# 5   https://api.openalex.org/works?filter=cites:W1...
# 6   https://api.openalex.org/works?filter=cites:W2...
# 7   https://api.openalex.org/works?filter=cites:W1...
# 8   https://api.openalex.org/works?filter=cites:W2...
# 9   https://api.openalex.org/works?filter=cites:W2...
# 10  https://api.openalex.org/works?filter=cites:W2...
# 11  https://api.openalex.org/works?filter=cites:W2...
#
#                                        counts_by_year  \
# 0   [{'year': 2022, 'cited_by_count': 2}, {'year':...
# 1   [{'year': 2022, 'cited_by_count': 1}, {'year':...
# 2   [{'year': 2020, 'cited_by_count': 1}, {'year':...
# 3                                                  []
# 4   [{'year': 2021, 'cited_by_count': 1}, {'year':...
# 5   [{'year': 2018, 'cited_by_count': 1}, {'year':...
# 6   [{'year': 2020, 'cited_by_count': 1}, {'year':...
# 7   [{'year': 2021, 'cited_by_count': 1}, {'year':...
# 8   [{'year': 2015, 'cited_by_count': 1}, {'year':...
# 9   [{'year': 2020, 'cited_by_count': 2}, {'year':...
# 10  [{'year': 2017, 'cited_by_count': 1}, {'year':...
# 11                                                 []
#
#                   updated_date created_date abstract_inverted_index
# 0   2022-07-18T07:59:55.091496   2019-04-25                     NaN
# 1   2022-08-08T14:38:03.684930   2020-11-23                     NaN
# 2   2022-07-29T23:04:50.458511   2017-03-16                     NaN
# 3                   2022-02-02   2016-06-24                     NaN
# 4                   2021-11-03   2016-06-24                     NaN
# 5   2022-08-14T15:06:41.294229   2016-06-24                     NaN
# 6   2022-08-12T19:49:55.432216   2016-06-24                     NaN
# 7                   2021-11-03   2016-06-24                     NaN
# 8                   2021-11-03   2016-06-24                     NaN
# 9   2022-08-14T20:29:58.030322   2016-06-24                     NaN
# 10                  2021-11-03   2016-06-24                     NaN
# 11                  2021-11-03   2016-06-24                     NaN
#
# [12 rows x 25 columns]

# %%
js = df.to_json('/content/drive/MyDrive/json/OpenAlex Condensed matter physics.json', orient = 'columns')
# Out:
# None
